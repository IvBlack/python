# %% [markdown]
# # Using numpy lib for ops over arrays, powerful tool of python.

# %%
a = [0,0,1,4,7,16,31,64,127]
import numpy as np
b = np.array(a)

# %%
b
# Out:
# array([  0,   0,   1,   4,   7,  16,  31,  64, 127])

# %%
c = np.array([1, 4., -2, 7])

# %%
c
# Out:
# array([ 1.,  4., -2.,  7.])

# %%
np.linspace(0, 45, 5)
# Out:
# array([ 0.  , 11.25, 22.5 , 33.75, 45.  ])

# %%
np.logspace(1, 3, 5)
# Out:
# array([  10.        ,   31.6227766 ,  100.        ,  316.22776602,
#        1000.        ])
