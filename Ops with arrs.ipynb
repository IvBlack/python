# %% [markdown]
# # Math ops with arrays, transform all the elements of array in one fell swoop.

# %%
import numpy as np
a = np.linspace(-1., 5, 7)
a
# Out:
# array([-1.,  0.,  1.,  2.,  3.,  4.,  5.])

# %%
a*6
# Out:
# array([-6.,  0.,  6., 12., 18., 24., 30.])

# %%
a/5
# Out:
# array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ])

# %%
a**3
# Out:
# array([ -1.,   0.,   1.,   8.,  27.,  64., 125.])

# %%
a+4
# Out:
# array([3., 4., 5., 6., 7., 8., 9.])

# %%
a-10
# Out:
# array([-11., -10.,  -9.,  -8.,  -7.,  -6.,  -5.])

# %%
(a+3)*2
# Out:
# array([ 4.,  6.,  8., 10., 12., 14., 16.])

# %%
np.sin(a)
# Out:
# array([-0.84147098,  0.        ,  0.84147098,  0.90929743,  0.14112001,
#        -0.7568025 , -0.95892427])

# %%
# %precision 4
np.sin(a)
# Out:
# array([-0.8415,  0.    ,  0.8415,  0.9093,  0.1411, -0.7568, -0.9589])
