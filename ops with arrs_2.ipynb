# %%
import numpy as np
a = np.linspace(-1., 5, 7)
a
# Out:
# array([-1.,  0.,  1.,  2.,  3.,  4.,  5.])

# %%
np.exp(-a)
# Out:
# array([2.71828183, 1.        , 0.36787944, 0.13533528, 0.04978707,
#        0.01831564, 0.00673795])

# %% [markdown]
# # %precision 4

# %%
np.exp(-a)
# Out:
# array([2.7183, 1.    , 0.3679, 0.1353, 0.0498, 0.0183, 0.0067])

# %%
1. + np.exp(-a)
# Out:
# array([3.7183, 2.    , 1.3679, 1.1353, 1.0498, 1.0183, 1.0067])

# %%
b = 5*np.ones(8)

# %%
b
# Out:
# array([5., 5., 5., 5., 5., 5., 5., 5.])

# %%
b+=4

# %%
b
# Out:
# array([9., 9., 9., 9., 9., 9., 9., 9.])

# %% [markdown]
# #Even fairly complex algebraic computations can be carried out this way.
